# %%
# !pip install bardapi
from bardapi import Bard
import os

# Replace XXXX with the values you get from __Secure-1PSID
os.environ['_BARD_API_KEY'] = "WwhLej6sEu-eZZ8qojaRem5l5e-SBDHlBeIxASJfhopwKhwzeCV0Uu0ZlYbWw-qu2ka9Aw."

while True:
    # Accept input from the user
    input_text = input("Please enter your input text (or 'q' to quit): ")
    
    # Check if the user wants to quit
    if input_text.lower() == 'q':
        print("Quitting...")
        break  # Exit the loop
    
    # Get the answer using the Bard API
    answer = Bard().get_answer(input_text)['content']
    
    # Display the answer
    print(answer)
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-bc0127b9-33c6-4bad-92fb-82b216491686/bin/python -m pip install --upgrade pip' command.
# Please enter your input text (or 'q' to quit):  hi
# Hi there! How can I help you today?
# Please enter your input text (or 'q' to quit):  whats your name
# You can call me Bard. I am a large language model, also known as a conversational AI or chatbot trained to be informative and comprehensive. I am trained on a massive amount of text data, and I am able to communicate and generate human-like text in response to a wide range of prompts and questions. For example, I can provide summaries of factual topics or create stories.
#
# I am still under development, but I have learned to perform many kinds of tasks, including
# * I will try my best to follow your instructions and complete your requests thoughtfully.
# ...
